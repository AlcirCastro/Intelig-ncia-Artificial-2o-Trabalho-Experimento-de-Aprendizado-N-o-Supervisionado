# %% [markdown]
# <a href="https://colab.research.google.com/github/AlcirCastro/Inteligencia-Artificial-2o-Trabalho-Experimento-de-Aprendizado-Nao-Supervisionado/blob/main/K_means_IA_Raised_sem_fore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Basic imports
import numpy as np
import pandas as pd

#sklearn imports
from sklearn.decomposition import PCA #Principal Component Analysis
from sklearn.manifold import TSNE #T-Distributed Stochastic Neighbor Embedding
from sklearn.cluster import KMeans #K-Means Clustering
from sklearn.preprocessing import StandardScaler #used for 'Feature Scaling'

#plotly imports
import plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
#df is our original DataFrame
df = pd.read_excel("StartUpsESG_0602.xlsx")

# %%
X = df.copy()
X.head()
# Out:
#       id          StartUp               Country  Year    ESG      E      S  \
# 0  12316      VenusEnergy             Lithuania  2018  0.010  0.008  0.002
# 1  23416  GreenEnergyCoin           Netherlands  2018  0.018  0.010  0.006
# 2   1553       HydroMiner               Austria  2017  0.014  0.010  0.000
# 3  17028        PowerCorp  Hong Kong SAR, China  2018  0.008  0.006  0.000
# 4   8483      Emyron Coin         United States  2018  0.017  0.000  0.011
#
#        G     Raised  distr_tk  ...   FISCALFRD    FINACIFRD    FOREIGINVEST   \
# 0  0.000  5986183.0      0.27  ...         96.7           70    1.299842e+09
# 1  0.002        0.0      0.00  ...         88.2           80   -3.614670e+11
# 2  0.004  3500000.0      0.00  ...         81.1           70   -2.855524e+10
# 3  0.002        0.0      0.00  ...        100.0           90    9.703626e+10
# 4  0.006        0.0      0.28  ...         54.8           80    2.614820e+11
#
#     FOREIGDP    INTERPAY    percmath    GINI    MAKTEFF    PERCTECH   \
# 0    2.420713    3.476571     4.26941    35.7   4.642995     3.11263
# 1  -39.565294    2.264509     6.37706    28.1   5.408080     2.82506
# 2   -6.277635    3.644302     6.07867    30.8   4.897589     4.38647
# 3   26.828457    0.050000     0.00000     0.0   5.705542     0.00000
# 4    1.268600   11.816379     7.20920    41.4   5.209139     3.78213
#
#     DEVCOUNT
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#
# [5 rows x 53 columns]

# %%
dicio = {}
count = 0

for index, pais in enumerate(df["Country"]):
  if pais in dicio:
    # Se estiver, atribuir o valor correspondente da classe
    X.loc[index, 'Classe_Country'] = dicio[pais]
  else:
    # Se não estiver, atribuir um novo valor de classe e atualizar o dicionário
    dicio[pais] = count
    X.loc[index, 'Classe_Country'] = count
    print("Pais: ",pais," ",count)
    count += 1
# Out:
# Pais:  Lithuania   0
# Pais:  Netherlands   1
# Pais:  Austria   2
# Pais:  Hong Kong SAR, China   3
# Pais:  United States   4
# Pais:  British Virgin Islands   5
# Pais:  Singapore   6
# Pais:  Russian Federation   7
# Pais:  Philippines   8
# Pais:  United Kingdom   9
# Pais:  Estonia   10
# Pais:  China   11
# Pais:  Switzerland   12
# Pais:  Belgium   13
# Pais:  Cayman Islands   14
# Pais:  Latvia   15
# Pais:  Portugal   16
# Pais:  Bosnia and Herzegovina   17
# Pais:  Luxembourg   18
# Pais:  Poland   19
# Pais:  Canada   20
# Pais:  Australia   21
# Pais:  Hungary   22
# Pais:  Germany   23
# Pais:  Finland   24
# Pais:  Georgia   25
# Pais:  Bulgaria   26
# Pais:  Italy   27
# Pais:  Norway   28
# Pais:  Romania   29
# Pais:  Malta   30
# Pais:  Ukraine   31
# Pais:  Cyprus   32
# Pais:  Spain   33
# Pais:  Turkey   34
# Pais:  Afghanistan   35
# Pais:  Indonesia   36
# Pais:  Gibraltar   37
# Pais:  Tanzania   38
# Pais:  France   39
# Pais:  Thailand   40
# Pais:  Israel   41
# Pais:  India   42
# Pais:  Jamaica   43
# Pais:  Samoa   44
# Pais:  Panama   45
# Pais:  Brazil   46
# Pais:  Czech Republic   47
# Pais:  Venezuela, RB   48
# Pais:  Costa Rica   49
# Pais:  Seychelles   50
# Pais:  Slovenia   51
# Pais:  Korea, Rep.   52
# Pais:  Belize   53
# Pais:  Argentina   54
# Pais:  Sweden   55
# Pais:  United Arab Emirates   56
# Pais:  South Africa   57
# Pais:  Japan   58
# Pais:  Chile   59
# Pais:  Croatia   60
# Pais:  Mauritius   61
# Pais:  Ireland   62
# Pais:  Mexico   63
# Pais:  Kazakhstan   64
# Pais:  Nigeria   65
# Pais:  Taiwan   66
# Pais:  Belarus   67
# Pais:  Dominican Republic   68
# Pais:  Denmark   69
# Pais:  Zimbabwe   70
# Pais:  Mongolia   71
# Pais:  Marshall Islands   72
# Pais:  St. Vincent and the Grenadines   73
# Pais:  Malaysia   74
# Pais:  St. Kitts and Nevis   75
# Pais:  Paraguay   76
# Pais:  Azerbaijan   77
# Pais:  Serbia   78
# Pais:  Sierra Leone   79
# Pais:  Iceland   80
# Pais:  Bahamas, The   81
# Pais:  Vietnam   82
# Pais:  Greece   83
# Pais:  North Macedonia   84
# Pais:  Egypt, Arab Rep.   85
# Pais:  Botswana   86
# Pais:  Sri Lanka   87
# Pais:  Slovak Republic   88
# Pais:  Oman   89
# Pais:  Kenya   90
# Pais:  Montenegro   91
# Pais:  Lao PDR   92
# Pais:  Morocco   93
# Pais:  New Zealand   94
# Pais:  Ecuador   95
# Pais:  Moldova   96
# Pais:  Peru   97
# Pais:  Colombia   98
# Pais:  Armenia   99
# Pais:  Syrian Arab Republic   100
# Pais:  Cambodia   101
# Pais:  St. Lucia   102
# Pais:  Ghana   103
# Pais:  Guinea-Bissau   104
# Pais:  Swaziland   105
# Pais:  Saudi Arabia   106
# Pais:  Tunisia   107
# Pais:  Bangladesh   108
# Pais:  Timor-Leste   109
# Pais:  india   110
# Pais:  Albania   111
# Pais:  Cameroon   112

# %%
X = X.drop(["StartUp","Country","id","Raised","Year"," FOREIGINVEST "],axis = 1)
X.head()
# Out:
#      ESG      E      S      G  distr_tk  Rating   platform ETHEREUM    kyc   \
# 0  0.010  0.008  0.002  0.000      0.27     3.9                    0      0
# 1  0.018  0.010  0.006  0.002      0.00     0.0                    1      0
# 2  0.014  0.010  0.000  0.004      0.00     0.0                    1      0
# 3  0.008  0.006  0.000  0.002      0.00     0.0                    0      0
# 4  0.017  0.000  0.011  0.006      0.28     2.4                    1      0
#
#     whitelist    mvp   ...   FISCALFRD    FINACIFRD    FOREIGDP    INTERPAY   \
# 0            0      0  ...         96.7           70    2.420713    3.476571
# 1            0      0  ...         88.2           80  -39.565294    2.264509
# 2            0      1  ...         81.1           70   -6.277635    3.644302
# 3            0      0  ...        100.0           90   26.828457    0.050000
# 4            0      0  ...         54.8           80    1.268600   11.816379
#
#     percmath    GINI    MAKTEFF    PERCTECH    DEVCOUNT   Classe_Country
# 0     4.26941    35.7   4.642995     3.11263           1             0.0
# 1     6.37706    28.1   5.408080     2.82506           1             1.0
# 2     6.07867    30.8   4.897589     4.38647           1             2.0
# 3     0.00000     0.0   5.705542     0.00000           1             3.0
# 4     7.20920    41.4   5.209139     3.78213           1             4.0
#
# [5 rows x 48 columns]

# %%
#Initialize our scaler
scaler = StandardScaler()

# %%
#Scale each column in numer
numer = pd.DataFrame(scaler.fit_transform(X))

# %%
#Initialize our model
kmeans = KMeans(n_clusters=3)

# %%
#Fit our model
kmeans.fit(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# KMeans(n_clusters
107,-340357.2320637637,-350024.2947811793,-340357.2240978493,-177033.77793175235,-340357.23578909173,-177033.7901383232,-351013.124259151,-177455.33844985542,-316407.22721684887,-341196.1058376907,-177033.79013833366,-340357.23339404725,-177033.74159011932,-357033.4280646682,-340367.8825496629,-357678.756808136,-356977.23611212545,-354335.4013448752,-340367.8861230983,-264743.10897240316,-356977.23998373206,-316407.24236180424,-340357.23620112,-177033.78641307403,-259807.4774873304,-351013.05934882455,-352972.46814681654,-355683.22346192744,-294915.07584468095,- ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cluster_means = X.groupby('Cluster').mean()

# Calcular a importância relativa das variáveis em relação ao cluster (por exemplo, diferença entre a média do cluster e a média global)
cluster_importance = cluster_means.subtract(X.mean())

# Plotar as importâncias relativas das variáveis
plt.figure(figsize=(10, 6))
sns.barplot(data=cluster_importance.abs().mean().sort_values(ascending=False).reset_index(), x='index', y=0, palette='viridis')
plt.title('Importância Relativa das Variáveis no Cluster')
plt.xlabel('Variável')
plt.ylabel('Importância Relativa Média')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-23-d8a255bcf99e>:11: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
plt.scatter(X["Cluster"],  X["E"], c=X["Cluster"], cmap='viridis', s=50)
plt.xlabel('Cluster')
plt.ylabel('E')
plt.title('Gráfico com Clusters no Eixo X')
plt.show()

# %%
plt.scatter(X["Cluster"],  X["S"], c=X["Cluster"], cmap='viridis', s=50)
plt.xlabel('Cluster')
plt.ylabel('S')
plt.title('Gráfico com Clusters no Eixo X')
plt.show()

# %%
plt.scatter(X["Cluster"],  X["G"], c=X["Cluster"], cmap='viridis', s=50)
plt.xlabel('Cluster')
plt.ylabel('G')
plt.title('Gráfico com Clusters no Eixo X')
plt.show()

# %%
X["Country"] = df["Country"]

cluster0 = X
# Criando o gráfico de barras

# Contando as ocorrências de cada item
plt.figure(figsize=(20,12))
# Criando o gráfico de barras
cluster0_sorted = cluster0.sort_values(by=" TEACHT ", ascending=False)

# Criando o gráfico de barras
plt.figure(figsize=(20,12))
plt.scatter(cluster0_sorted['Country'], cluster0_sorted[" TEACHT "], c=cluster0_sorted["Cluster"], cmap='viridis', s=50)

# Adicionando rótulos aos eixos
plt.xlabel('Países')
plt.ylabel(" FOREIGINVEST ")
plt.xticks(rotation=90)

# Adicionando título ao gráfico
plt.title('FOREIGINVEST por País (Cluster 0)')

# Exibindo o gráfico
plt.show()

# %%
plt.scatter(X["Cluster"],  X["ESG"], c=X["Cluster"], cmap='viridis', s=50)
plt.xlabel('Cluster')
plt.ylabel('G')
plt.title('Gráfico com Clusters no Eixo X')
plt.show()

# %%
cluster0 = df.loc[df["Cluster"] == 0]
cluster0 = cluster0[["ESG", "Raised", "E", "S", "G"]]
cluster0.describe()
# Out:
#                ESG        Raised            E            S            G
# count  4788.000000  4.788000e+03  4788.000000  4788.000000  4788.000000
# mean      0.000901  4.112445e+06     0.000175     0.000459     0.000316
# std       0.002900  2.362579e+07     0.001723     0.001822     0.001193
# min       0.000000  0.000000e+00     0.000000     0.000000     0.000000
# 25%       0.000000  0.000000e+00     0.000000     0.000000     0.000000
# 50%       0.000000  0.000000e+00     0.000000     0.000000     0.000000
# 75%       0.000000  1.250000e+06     0.000000     0.000000     0.000000
# max       0.044000  1.000000e+09     0.080000     0.040000     0.020000

# %%
cluster0 = df.loc[df["Cluster"] == 1]
cluster0 = cluster0[["ESG", "Raised", "E", "S", "G"]]
cluster0.describe()
# Out:
#                ESG        Raised            E            S            G
# count  1072.000000  1.072000e+03  1072.000000  1072.000000  1072.000000
# mean      0.000871  4.876909e+06     0.000093     0.000519     0.000275
# std       0.003166  1.900026e+07     0.000868     0.002523     0.001044
# min       0.000000  0.000000e+00     0.000000     0.000000     0.000000
# 25%       0.000000  0.000000e+00     0.000000     0.000000     0.000000
# 50%       0.000000  0.000000e+00     0.000000     0.000000     0.000000
# 75%       0.000000  7.126778e+05     0.000000     0.000000     0.000000
# max       0.060000  2.975275e+08     0.014000     0.060000     0.011000

# %%
cluster0 = df.loc[df["Cluster"] == 2]
cluster0 = cluster0[["ESG", "Raised", "E", "S", "G"]]
cluster0.describe()
# Out:
#               ESG        Raised           E           S           G
# count  681.000000  6.810000e+02  681.000000  681.000000  681.000000
# mean     0.000885  2.703745e+06    0.000241    0.000476    0.000329
# std      0.002900  8.850071e+06    0.001634    0.002143    0.002422
# min      0.000000  0.000000e+00    0.000000    0.000000    0.000000
# 25%      0.000000  0.000000e+00    0.000000    0.000000    0.000000
# 50%      0.000000  0.000000e+00    0.000000    0.000000    0.000000
# 75%      0.000000  7.844960e+05    0.000000    0.000000    0.000000
# max      0.040000  1.000000e+08    0.020000    0.040000    0.060000
